# %%
import matplotlib.pyplot as py
import numpy as np
import pandas as pd
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(include='category')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
insights
describe gives numerical columns
dataset has 244 records
No missing values in total_bill,tip,size
since mean and median are not same it is not normal distribution
the average group size is 2-3 people

# %%
#null value treatment and imputation
A.Fill the missing records
  1.Mean median mode
  2.domain
B.Remove the missing data
  1.Remove the rows in which missing position
     dropna data loss less than 20
  2.remove the columns in which missing positions

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.isna().sum() #to find no.of missing values in each column
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna() #to remove missing value records temporarily
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dropna().shape #number of records after removing missing records
# Out:
# (182, 15)

# %%
df.shape
# Out:
# (891, 15)

# %%
df.shape[0]
# Out:
# 891

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100 #loss percentage
# Out:
# 79.57351290684625

# %%
((891-182)/891)*100
# Out:
# 79.57351290684625

# %%
(df.isna().sum()/df.shape[0])*100 #percentage of missing records
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df=df.drop('deck',axis=1) #to remove a column where axis=1 indicates coloumns,axis=0 indicates rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    object
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(1), int64(4), object(6)
# memory usage: 79.4+ KB

# %%
df['age'].fillna(df['age'].median(),inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)

# %%
# numerical columns
survived
age
pclass 
sibsp
parch
fare

# %%
py.figure(figsize=(3,3))   #univaroate analysis for numericaldata
sns.histplot(x=df['survived'])
py.show()

# %%
py.figure(figsize=(3,3))   #univaroate analysis for numericaldata
sns.histplot(x=df['age'])
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'])
py.show()

# %%
py.figure(figsize=(3,3))            
sns.histplot(x=df['pclass'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))            
sns.histplot(x=df['parch'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))            
sns.histplot(x=df['fare'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))         #univariate analysis for categorical data   
sns.countplot(x=df['sex'])
py.show()

# %%
py.figure(figsize=(3,3))            
sns.countplot(x=df['class'])
py.show()

# %%
py.figure(figsize=(3,3))            
sns.countplot(x=df['embarked'])
py.show()

# %%
py.figure(figsize=(3,3))            
sns.countplot(x=df['who'])
py.show()

# %%
py.figure(figsize=(3,3))            
sns.countplot(x=df['adult_male'])
py.show()

# %%
py.figure(figsize=(3,3))            
sns.countplot(x=df['embark_town'])
py.show()

# %%
py.figure(figsize=(3,3))            
sns.countplot(x=df['alive'])
py.show()

# %%
py.figure(figsize=(3,3))            
sns.countplot(x=df['alone'])
py.show()

# %%
# bivariate analysis

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'],hue=df['sex'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['pclass'],hue=df['sex'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['parch'],hue=df['sex'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['fare'],hue=df['sex'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['survived'],hue=df['sex'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['age'],hue=df['sex'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['survived'],hue=df['embarked'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['age'],hue=df['embarked'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['pclass'],hue=df['embarked'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['parch'],hue=df['embarked'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['fare'],hue=df['embarked'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'],hue=df['embarked'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['survived'],hue=df['class'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['age'],hue=df['class'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'],hue=df['class'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['parch'],hue=df['class'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['fare'],hue=df['class'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['pclass'],hue=df['class'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['survived'],hue=df['who'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['age'],hue=df['who'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['pclass'],hue=df['who'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'],hue=df['who'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['fare'],hue=df['who'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['parch'],hue=df['who'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['survived'],hue=df['adult_male'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['age'],hue=df['adult_male'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['pclass'],hue=df['adult_male'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'],hue=df['adult_male'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['parch'],hue=df['adult_male'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['fare'],hue=df['adult_male'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['survived'],hue=df['embark_town'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['age'],hue=df['embark_town'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['pclass'],hue=df['embark_town'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'],hue=df['embark_town'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['parch'],hue=df['embark_town'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['fare'],hue=df['embark_town'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['survived'],hue=df['alive'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['age'],hue=df['alive'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['pclass'],hue=df['alive'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'],hue=df['alive'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['fare'],hue=df['alive'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['parch'],hue=df['alive'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.histplot(x=df['survived'],hue=df['alone'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['age'],hue=df['alone'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['pclass'],hue=df['alone'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['sibsp'],hue=df['alone'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['parch'],hue=df['alone'],kde=True)
py.show()
py.figure(figsize=(3,3))
sns.histplot(x=df['fare'],hue=df['alone'],kde=True)
py.show()

# %%
py.figure(figsize=(3,3))
sns.countplot(x=df['embarked'],hue=df['sex'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['class'],hue=df['sex'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['who'],hue=df['sex'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['embark_town'],hue=df['sex'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['adult_male'],hue=df['sex'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alive'],hue=df['sex'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alone'],hue=df['sex'])
py.show()

# %%
py.figure(figsize=(3,3))
sns.countplot(x=df['class'],hue=df['embarked'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['who'],hue=df['embarked'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['embark_town'],hue=df['embarked'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['adult_male'],hue=df['embarked'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alive'],hue=df['embarked'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alone'],hue=df['embarked'])
py.show()

# %%
py.figure(figsize=(3,3))
sns.countplot(x=df['who'],hue=df['class'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['embark_town'],hue=df['class'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['adult_male'],hue=df['class'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alive'],hue=df['class'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alone'],hue=df['class'])
py.show()

# %%
py.figure(figsize=(3,3))
sns.countplot(x=df['embark_town'],hue=df['who'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['adult_male'],hue=df['who'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alive'],hue=df['who'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alone'],hue=df['who'])
py.show()

# %%
py.figure(figsize=(3,3))
sns.countplot(x=df['adult_male'],hue=df['embark_town'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alive'],hue=df['embark_town'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alone'],hue=df['embark_town'])
py.show()

# %%
py.figure(figsize=(3,3))
sns.countplot(x=df['alive'],hue=df['adult_male'])
py.show()
py.figure(figsize=(3,3))
sns.countplot(x=df['alone'],hue=df['adult_male'])
py.show()

# %%
py.figure(figsize=(3,3))
sns.countplot(x=df['alone'],hue=df['alive'])
py.show()

# %%
py.figure(figsize=(3,3))
sns.countplot(x=df['alone'],hue=df['alone'])
py.show()
